# %% [markdown]
# # Temperature and Rainfall Analysis using PyCaret - Time Series Forecasting

# %% [markdown]
# ### Step 1: Merging the dataset

# %%
import pandas as pd

temperature_df = pd.read_excel('dataset/Temp_SRS_1Jan1964_to_31Oct2020.xlsx')
rainfall_df = pd.read_csv('dataset/Rainfall_at_SRS_30Nov1960_to_18Nov2020.csv')

rainfall_df = rainfall_df.fillna(0)

temperature_df['DATE'] = pd.to_datetime(temperature_df['DATE'], format='%Y-%m-%d')
rainfall_df['DATE'] = pd.to_datetime(rainfall_df['DATE'], format='%m/%d/%Y')

temperature_df['YEAR'] = pd.to_datetime(temperature_df.DATE).dt.year
rainfall_df['YEAR'] = pd.to_datetime(rainfall_df.DATE).dt.year

temperature_df_grouped = temperature_df.groupby('YEAR').agg({'LOW TEMP': 'mean', 'HIGH TEMP': 'mean'})
temperature_df_grouped['RAINFALL'] = rainfall_df.groupby('YEAR').agg({'200-F Rainfall (inches/day)': 'mean'})
rain_temp_df = pd.merge(temperature_df, rainfall_df, on='DATE')

temperature_df_grouped.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/gn/703bzhfx6vd8q6q9btr5325r0000gn/T/ipykernel_50899/2945237905.py in ?()
# ---> 19 import pandas as pd
#      20
#      21 temperature_df = pd.read_excel('dataset/Temp_SRS_1Jan1964_to_31Oct2020.xlsx')
#      22 rainfall_df = pd.read_csv('dataset/Rainfall_at_SRS_30Nov1960_to_18Nov2020.csv')
#
# ~/anaconda3/envs/denv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'YEAR'

# %% [markdown]
# ### Step 2: Using PyCaret for exploration

# %%
from pycaret.time_series import *

s = setup(temperature_df_grouped, target='RAINFALL', fh=11)
# check_stats()

# print(f"Train: ${get_config('y_train').index}")

# print(f"Test: ${get_config('y_test').index}")

best = compare_models(errors="raise")

print(best)
# Out:
# <style type="text/css">
# #T_52962_row28_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_52962">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52962_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_52962_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52962_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52962_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_52962_row0_col1" class="data row0 col1" >2472</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_52962_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_52962_row1_col1" class="data row1 col1" >RAINFALL</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_52962_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_52962_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_52962_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_52962_row3_col1" class="data row3 col1" >Present</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_52962_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_52962_row4_col1" class="data row4 col1" >(57, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_52962_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_52962_row5_col1" class="data row5 col1" >(57, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_52962_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_52962_row6_col1" class="data row6 col1" >(46, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_52962_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_52962_row7_col1" class="data row7 col1" >(11, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_52962_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_52962_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_52962_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_52962_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_52962_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_52962_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_52962_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_52962_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_52962_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_52962_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_52962_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_52962_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_52962_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_52962_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_52962_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_52962_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_52962_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_52962_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_52962_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_52962_row17_col1" class="data row17 col1" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_52962_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_52962_row18_col1" class="data row18 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_52962_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_52962_row19_col1" class="data row19 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_52962_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_52962_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_52962_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_52962_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_52962_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_52962_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_52962_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_52962_row23_col1" class="data row23 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_52962_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_52962_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_52962_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_52962_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_52962_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_52962_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_52962_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_52962_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_52962_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_52962_row28_col1" class="data row28 col1" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_52962_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_52962_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_52962_level0_row30" class="row_heading level0 row30" >30</th>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          20:35:17
# Status     . . . . . . . . . . . . . . . . . .   Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Naive Forecaster
# Empty DataFrame
# Columns: [Model, MASE, RMSSE, MAE, RMSE, MAPE, SMAPE, R2, TT (Sec)]
# Index: []
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 428, in _process_worker
#     r = call_item()
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 275, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 620, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/utils/time_series/forecasting/model_selection.py", line 178, in _fit_and_score
#     y_pred, lower, upper = get_predictions_with_intervals(
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/utils/time_series/forecasting/__init__.py", line 110, in get_predictions_with_intervals
#     y_pred = forecaster.predict(fh=fh, X=X)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/sktime/forecasting/base/_base.py", line 405, in predict
#     y_pred = self._predict(fh=fh, X=X_inner)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/sktime/forecasting/compose/_pipeline.py", line 517, in _predict
#     return self.forecaster_.predict(fh, X)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/sktime/forecasting/base/_base.py", line 405, in predict
#     y_pred = self._predict(fh=fh, X=X_inner)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/sktime/forecasting/compose/_pipeline.py", line 1008, in _predict
#     y_pred = self.forecaster_.predict(fh=fh, X=X)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/sktime/forecasting/base/_base.py", line 405, in predict
#     y_pred = self._predict(fh=fh, X=X_inner)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/sktime/forecasting/naive.py", line 336, in _predict
#     y_pred = super(NaiveForecaster, self)._predict(fh=fh, X=X)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/sktime/forecasting/base/_sktime.py", line 31, in _predict
#     y_pred = self._predict_fixed_cutoff(
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/sktime/forecasting/base/_sktime.py", line 78, in _predict_fixed_cutoff
#     return pd.Series(y_pred, index=index)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/pandas/core/series.py", line 425, in __init__
#     index = ensure_index(index)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 7125, in ensure_index
#     return Index(index_like, copy=copy)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 522, in __new__
#     raise cls._raise_scalar_data_error(data)
#   File "/Users/sagunraj/anaconda3/envs/denv/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 5065, in _raise_scalar_data_error
#     raise TypeError(
# TypeError: Index(...) must be called with a collection of some kind, ForecastingHorizon([1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987], dtype='int64', is_relative=False) was passed
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 10
#       3 s = setup(temperature_df_grouped, target='RAINFALL', fh=11)
#       4 # check_stats()
#       5
#       6 # print(f"Train: ${get_config('y_train').index}")
#       7
#       8 # print(f"Test: ${get_config('y_test').index}")
# ---> 10 best = compare_models(errors="raise")
#      12 print(best)
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/utils/generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/time_series/forecasting/functional.py:757, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, engine, verbose, parallel)
#     637 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#     638 def compare_models(
#     639     include: Optional[List[Union[str, Any]]] = None,
#    (...)
#     652     parallel: Optional[ParallelBackend] = None,
#     653 ):
#     654     """
#     655     This function trains and evaluates performance of all estimators available in the
#     656     model library using cross validation. The output of this function is a score grid
#    (...)
#     754
#     755     """
# --> 757     return _CURRENT_EXPERIMENT.compare_models(
#     758         include=include,
#     759         exclude=exclude,
#     760         fold=fold,
#     761         round=round,
#     762         cross_validation=cross_validation,
#     763         sort=sort,
#     764         n_select=n_select,
#     765         budget_time=budget_time,
#     766         turbo=turbo,
#     767         errors=errors,
#     768         fit_kwargs=fit_kwargs,
#     769         engine=engine,
#     770         verbose=verbose,
#     771         parallel=parallel,
#     772     )
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/time_series/forecasting/oop.py:2317, in TSForecastingExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, experiment_custom_tags, engine, verbose, parallel)
#    2314         self._set_engine(estimator=estimator, engine=eng, severity="error")
#    2316 try:
# -> 2317     return_values = super().compare_models(
#    2318         include=include,
#    2319         exclude=exclude,
#    2320         fold=fold,
#    2321         round=round,
#    2322         cross_validation=cross_validation,
#    2323         sort=sort,
#    2324         n_select=n_select,
#    2325         budget_time=budget_time,
#    2326         turbo=turbo,
#    2327         errors=errors,
#    2328         fit_kwargs=fit_kwargs,
#    2329         experiment_custom_tags=experiment_custom_tags,
#    2330         verbose=verbose,
#    2331         parallel=parallel,
#    2332         caller_params=caller_params,
#    2333     )
#    2334 finally:
#    2335     if engine is not None:
#    2336         # Reset the models back to the default engines
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:788, in _SupervisedExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, parallel, caller_params)
#     786 results_columns_to_ignore = ["Object", "runtime", "cutoff"]
#     787 if errors == "raise":
# --> 788     model, model_fit_time = self._create_model(**create_model_args)
#     789     model_results = self.pull(pop=True)
#     790 else:
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:1519, in _SupervisedExperiment._create_model(self, estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, probability_threshold, experiment_custom_tags, verbose, system, add_to_model_list, X_train_data, y_train_data, metrics, display, model_only, return_train_score, **kwargs)
#    1516         return model, model_fit_time
#    1517     return model
# -> 1519 model, model_fit_time, model_results, _ = self._create_model_with_cv(
#    1520     model,
#    1521     data_X,
#    1522     data_y,
#    1523     fit_kwargs,
#    1524     round,
#    1525     cv,
#    1526     groups,
#    1527     metrics,
#    1528     refit,
#    1529     system,
#    1530     display,
#    1531     return_train_score=return_train_score,
#    1532 )
#    1534 # end runtime
#    1535 runtime_end = time.time()
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/time_series/forecasting/oop.py:2648, in TSForecastingExperiment._create_model_with_cv(self, model, data_X, data_y, fit_kwargs, round, cv, groups, metrics, refit, system, display, return_train_score)
#    2643 pipeline_with_model = _add_model_to_pipeline(
#    2644     pipeline=self.pipeline, model=model
#    2645 )
#    2647 with redirect_output(self.logger):
# -> 2648     scores, cutoffs = cross_validate(
#    2649         pipeline=pipeline_with_model,
#    2650         y=data_y,
#    2651         X=data_X,
#    2652         scoring=metrics_dict,
#    2653         cv=cv,
#    2654         n_jobs=n_jobs,
#    2655         verbose=0,
#    2656         fit_params=fit_kwargs,
#    2657         return_train_score=False,
#    2658         alpha=self.point_alpha,
#    2659         coverage=self.coverage,
#    2660         error_score=0,
#    2661         **additional_scorer_kwargs,
#    2662     )
#    2664 model_fit_end = time.time()
#    2665 model_fit_time = np.array(model_fit_end - model_fit_start).round(2)
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/utils/time_series/forecasting/model_selection.py:309, in cross_validate(pipeline, y, X, cv, scoring, fit_params, n_jobs, return_train_score, alpha, coverage, error_score, verbose, **additional_scorer_kwargs)
#     306     scoring = _get_metrics_dict(scoring)
#     307     parallel = Parallel(n_jobs=n_jobs)
# --> 309     out = parallel(
#     310         delayed(_fit_and_score)(
#     311             pipeline=clone(pipeline),
#     312             y=y,
#     313             X=X,
#     314             scoring=scoring,
#     315             train=train,
#     316             test=test,
#     317             parameters=None,
#     318             fit_params=fit_params,
#     319             return_train_score=return_train_score,
#     320             alpha=alpha,
#     321             coverage=coverage,
#     322             error_score=error_score,
#     323             **additional_scorer_kwargs,
#     324         )
#     325         for train, test in get_folds(cv, y)
#     326     )
#     327 # raise key exceptions
#     328 except Exception:
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~/anaconda3/envs/denv/lib/python3.9/concurrent/futures/_base.py:446, in Future.result(self, timeout)
#     444     raise CancelledError()
#     445 elif self._state == FINISHED:
# --> 446     return self.__get_result()
#     447 else:
#     448     raise TimeoutError()
#
# File ~/anaconda3/envs/denv/lib/python3.9/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# TypeError: Index(...) must be called with a collection of some kind, ForecastingHorizon([1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987], dtype='int64', is_relative=False) was passed

# %%
plot_model(best, plot='forecast')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plot_model(best, plot='forecast')
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/utils/generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/time_series/forecasting/functional.py:1399, in plot_model(estimator, plot, return_fig, return_data, verbose, display_format, data_kwargs, fig_kwargs, save)
#    1163 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1164 def plot_model(
#    1165     estimator: Optional[Any] = None,
#    (...)
#    1173     save: Union[str, bool] = False,
#    1174 ) -> Optional[Tuple[str, list]]:
#    1175     """
#    1176     This function analyzes the performance of a trained model on holdout set.
#    1177     When used without any estimator, this function generates plots on the
#    (...)
#    1396
#    1397     """
# -> 1399     return _CURRENT_EXPERIMENT.plot_model(
#    1400         estimator=estimator,
#    1401         plot=plot,
#    1402         return_fig=return_fig,
#    1403         return_data=return_data,
#    1404         display_format=display_format,
#    1405         data_kwargs=data_kwargs,
#    1406         fig_kwargs=fig_kwargs,
#    1407         save=save,
#    1408     )
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/time_series/forecasting/oop.py:4193, in TSForecastingExperiment.plot_model(self, estimator, plot, return_fig, return_data, verbose, display_format, data_kwargs, fig_kwargs, save)
#    4190 system = os.environ.get("PYCARET_TESTING", "0")
#    4191 system = system == "0"
# -> 4193 return self._plot_model(
#    4194     estimator=estimator,
#    4195     plot=plot,
#    4196     return_fig=return_fig,
#    4197     return_data=return_data,
#    4198     verbose=verbose,
#    4199     display_format=display_format,
#    4200     data_kwargs=data_kwargs,
#    4201     fig_kwargs=fig_kwargs,
#    4202     save=save,
#    4203     system=system,
#    4204 )
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/time_series/forecasting/oop.py:3823, in TSForecastingExperiment._plot_model(self, estimator, plot, return_fig, return_data, verbose, display_format, data_kwargs, fig_kwargs, system, save)
#    3815         plots_formatted_model = [
#    3816             f"'{plot}'" for plot in self._available_plots_estimator_keys
#    3817         ]
#    3818         raise ValueError(
#    3819             f"Plot type '{plot}' is not supported when estimator is provided. "
#    3820             f"Available plots are: {', '.join(plots_formatted_model)}"
#    3821         )
# -> 3823 fig, plot_data = _get_plot(
#    3824     plot=plot,
#    3825     fig_defaults=self.fig_kwargs,
#    3826     data=data,
#    3827     data_label=data_label,
#    3828     X=X,
#    3829     X_labels=X_labels,
#    3830     cv=cv,
#    3831     model_results=model_results,
#    3832     model_labels=model_labels,
#    3833     return_pred_int=return_pred_int,
#    3834     data_kwargs=data_kwargs,
#    3835     fig_kwargs=fig_kwargs,
#    3836 )
#    3838 # Sometimes the plot is not successful, such as decomp with RangeIndex.
#    3839 # In such cases, plotting should be bypassed.
#    3840 if fig is not None:
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/internal/plots/time_series.py:162, in _get_plot(plot, fig_defaults, data, data_label, X, X_labels, cv, model_results, model_labels, return_pred_int, data_kwargs, fig_kwargs)
#     153         fig, plot_data = plot_predictions_with_confidence(
#     154             data=data,
#     155             predictions=model_results,
#    (...)
#     159             fig_kwargs=fig_kwargs,
#     160         )
#     161     else:
# --> 162         fig, plot_data = plot_model_results(
#     163             original_data=data,
#     164             model_results=model_results,
#     165             model_labels=model_labels,
#     166             plot=plot,
#     167             fig_defaults=fig_defaults,
#     168             hoverinfo=hoverinfo,
#     169             fig_kwargs=fig_kwargs,
#     170         )
#     171 elif plot == "ccf":
#     172     fig, plot_data = plot_ccf(
#     173         y=data,
#     174         y_label=data_label,
#    (...)
#     178         fig_kwargs=fig_kwargs,
#     179     )
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pycaret/internal/plots/time_series.py:572, in plot_model_results(original_data, model_results, model_labels, plot, fig_defaults, hoverinfo, fig_kwargs)
#     570 if plot in ["forecast", "insample"]:
#     571     model_results = [model_result["y_pred"] for model_result in model_results]
# --> 572 model_results = pd.concat(model_results, axis=1)
#     573 model_results.columns = model_labels
#     575 if plot == "forecast":
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pandas/core/reshape/concat.py:372, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     369 elif copy and using_copy_on_write():
#     370     copy = False
# --> 372 op = _Concatenator(
#     373     objs,
#     374     axis=axis,
#     375     ignore_index=ignore_index,
#     376     join=join,
#     377     keys=keys,
#     378     levels=levels,
#     379     names=names,
#     380     verify_integrity=verify_integrity,
#     381     copy=copy,
#     382     sort=sort,
#     383 )
#     385 return op.get_result()
#
# File ~/anaconda3/envs/denv/lib/python3.9/site-packages/pandas/core/reshape/concat.py:429, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     426     objs = list(objs)
#     428 if len(objs) == 0:
# --> 429     raise ValueError("No objects to concatenate")
#     431 if keys is None:
#     432     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate
